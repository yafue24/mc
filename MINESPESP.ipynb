# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.19.4' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'mohist':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# https://papermc.io/api/v2/projects/paper/versions/1.19.4/builds/550/downloads/paper-1.19.4-550.jar
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2coyu16gdQDh5ebZfhNgliT0dxF_7AbHSbtCBnL9xMwPKpc1s" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      forge.jar	    mohist.jar	       user_jvm_args.txt
# banned-players.json  forge.jar.log  mundo2	       usercache.json
# bukkit.yml	     help.yml	    ops.json	       usernamecache.json
# colabconfig.json     journeymap     permissions.yml    wepif.yml
# commands.yml	     libraries	    plugins	       whitelist.json
# config		     localconfigs   run.bat	       world
# crash-reports	     logs	    run.sh
# defaultconfigs	     mods	    server.properties
# eula.txt	     mohist-config  spigot.yml
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 6.tcp.ngrok.io:17600
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#
#  __    __   ______   __  __   __   ______   ______
# /\ "-./  \ /\  __ \ /\ \_\ \ /\ \ /\  ___\ /\__  _\
# \ \ \-./\ \\ \ \/\ \\ \  __ \\ \ \\ \___  \\/_/\ \/
#  \ \_\ \ \_\\ \_____\\ \_\ \_\\ \_\\/\_____\  \ \_\
#   \/_/  \/_/ \/_____/ \/_/\/_/ \/_/ \/_____/   \/_/
#
#
#                                       Welcome to Mohist ! - Mohist Developement Group - 1.19.4-195, Java 65.0
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is {0} but you have {1}. The latest version has been built on {2}. You should update to fix recent bugs !
# Checking libraries, please wait...
# DownloadSource: {0}
# All libraries are nice :) !
# [08:07:15 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 45.2.0, --fml.mcVersion, 1.19.4, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230314.122934, nogui]
# [08:07:15 INFO]: ModLauncher 10.0.8+10.0.8+main.0ef7e830 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.5.0-1022-azure
# [08:07:17 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2392!/ Service=ModLauncher Env=SERVER
# [08:07:18 INFO]: Found 4 dependencies adding them to mods collection
# [08:07:21 INFO]: Compatibility level set to JAVA_17
# [08:07:21 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [08:07:21 WARN]: Reference map 'cookingforblockheads.refmap.json' for cookingforblockheads.mixins.json could not be read. If this is a development environment you can ignore this message
# [08:07:21 WARN]: Reference map 'coroutil.refmap.json' for coroutil.mixins.json could not be read. If this is a development environment you can ignore this message
# [08:07:21 WARN]: Reference map 'apexcore.refmap.json' for apexcore.mixins.json could not be read. If this is a development environment you can ignore this message
# [08:07:31 INFO]: Constructing common components for mod betteranimationscollection
# [08:07:31 INFO]: [Dynamic Lights] Registering server started event...
# [08:07:31 INFO]: Initialize mod Library Ferret
# [08:07:31 INFO]: Initialized mod Library Ferret
# [08:07:31 INFO]: Constructing common components for mod pickupnotifier
# [08:07:31 INFO]: forge loader environment detected
# [08:07:31 INFO]: Forge mod loading, version 45.2.0, for MC 1.19.4 with MCP 20230314.122934
# [08:07:31 INFO]: MinecraftForge v45.2.0 Initialized
# [08:07:31 INFO]: Mohist loading.....
# [08:07:32 INFO]: EventDispatcherRegistry initialized
# [08:07:32 INFO]: Running Minecraft '1.19.4', & Forge '45.2.0' on Java '21.0.2, Microsoft'
# [08:07:32 INFO]: Loading BlackListed sources from remote... (https://api.stopmodreposts.org/minecraft/sites.txt)
# [08:07:32 INFO]: Initializing Update Checker...
# [08:07:32 INFO]: Starting Update Check...
# [08:07:32 INFO]: Update Check done!
# [08:07:32 INFO]: Iron Furnaces is up to date!
# [08:07:32 INFO]: Loaded 564 BlackListed sources from remote
# [08:07:32 INFO]: Loading mod 'commonality' TrustWorthiness...
# [08:07:32 FATAL]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [08:07:32 INFO]: Loaded mod 'commonality' TrustWorthiness: UNKNOWN
# [08:07:32 INFO]: Constructing common components for mod hangglider
# [08:07:32 INFO]: Simple Farming setup complete!
# [08:07:32 INFO]: Hello world!
# [08:07:32 INFO]: Constructing common components for mod bettertridents
# [08:07:32 INFO]: Loading mod 'apexcore' TrustWorthiness...
# [08:07:32 FATAL]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [08:07:32 INFO]: Loaded mod 'apexcore' TrustWorthiness: UNKNOWN
# [08:07:32 INFO]: Loading mod 'fantasyfurniture' TrustWorthiness...
# [08:07:32 FATAL]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [08:07:32 INFO]: Loaded mod 'fantasyfurniture' TrustWorthiness: UNKNOWN
# [08:07:32 INFO]: Constructing common components for mod puzzleslib
# [08:07:33 INFO]: Constructing common components for mod enchantinginfuser
# [08:07:36 INFO]: Initialized block sets in 8ms
# [08:07:36 INFO]: Loading common config for bettertridents
# [08:07:36 INFO]: Reloading common config for bettertridents
# [08:07:36 INFO]: Reloading common config for bettertridents
# [08:07:36 INFO]: [Dynamic Lights] Loaded Dynamic Lights by Tschipcraft successfully!
# [08:07:36 INFO]: [voicechat] Compatibility version 17
# [08:07:36 INFO]: Global Forge version check system disabled, no further processing.
# [08:07:36 INFO]: medievalmusic mod initialized
# [08:07:36 INFO]: betterfpsdist mod initialized
# t=2024-07-27T08:07:36+0000 lvl=warn msg="failed to open private leg" id=f4433ba534b4 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [08:07:36 INFO]: biomemusic mod initialized
# [08:07:36 INFO]: [voicechat] Loading plugins
# [08:07:36 INFO]: [voicechat] Loaded 0 plugin(s)
# [08:07:36 INFO]: [voicechat] Initializing plugins
# [08:07:36 INFO]: [voicechat] Initialized 0 plugin(s)
# [08:07:36 INFO]: Initializing Packet Registries
# [08:07:37 INFO]: Registered the FluidEffect with Unique ID of minecraft:water for Water (Fluid Amount Required: 1000) with the ID 0
# [08:07:37 INFO]: Registered the FluidEffect with Unique ID of minecraft:lava for Lava (Fluid Amount Required: 1000) with the ID 1
# [08:07:37 INFO]: Registered the FluidEffect with Unique ID of travelersbackpack:potion for Uncraftable Potion (Fluid Amount Required: 250) with the ID 2
# [08:07:37 INFO]: Registered the FluidEffect with Unique ID of minecraft:milk for Milk (Fluid Amount Required: 1000) with the ID 3
# [08:07:37 INFO]: Finished mod setup in: [0, 1, 25, 0, 1, 0, 0, 9, 1] ms
# [08:07:37 INFO]: Initialized color sets in 25ms
# [08:07:37 INFO]: Got IMC []
# [08:07:37 INFO]: Automatic pull animal configuration:
# pull_animals = [
#     "minecraft:camel",
#     "minecraft:donkey",
#     "minecraft:horse",
#     "minecraft:mule",
#     "minecraft:skeleton_horse",
#     "minecraft:zombie_horse",
#     "minecraft:player"
#   ]
# t=2024-07-27T08:07:37+0000 lvl=warn msg="failed to open private leg" id=0e9ea1106ab8 typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [08:07:42 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [08:07:45 INFO]: Generated runtime SERVER_DATA for pack Supplementaries Generated Pack in: 58 ms
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_5_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_4_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe supplementaries:inspirations/blackboard_clear as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe supplementaries:inspirations/flag_clear as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:belt_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_6_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_1_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe supplementaries:inspirations/flag_dye as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_7_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_2_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Skipping loading recipe toolbelt:pouch_upgrade_3_via_sewing as it's serializer returned null
# [08:07:47 INFO]: Loaded 10 recipes
# [08:07:47 INFO]: Loaded 1859 advancements
# [08:07:47 INFO]: Loaded  8 flute songs
# [08:07:47 WARN]: Not all defined tags for registry ResourceKey[minecraft:root / minecraft:worldgen/structure] are present in data pack: minecraft:shipwrech
# [08:07:50 INFO]: Finished additional setup in 47 ms
# [08:07:50 INFO]: Starting minecraft server version 1.19.4
# [08:07:50 INFO]: Loading properties
# [08:07:50 INFO]: Default game type: SURVIVAL
# [08:07:50 INFO]: Generating keypair
# [08:07:50 INFO]: Starting Minecraft server on *:25565
# [08:07:50 INFO]: Using epoll channel type
# [08:07:51 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [08:07:51 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [08:07:51 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [08:07:51 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [08:07:51 INFO]: This server is running Mohist version 1.19.4-195 (MC: 1.19.4) (Implementing API version 1.19.4-R0.1-SNAPSHOT, Forge version 45.2.0)
# [08:07:52 INFO]: Debug logging is enabled
# [08:07:52 INFO]: Server Ping Player Sample Count: 12
# [08:07:52 INFO]: Using 4 threads for Netty based IO
# [08:07:52 ERROR]: Could not load 'plugins/SetHome-6.2.3.jar' in folder 'plugins'
# org.bukkit.plugin.InvalidPluginException: Unsupported API version 1.20
# 	at org.bukkit.craftbukkit.v1_19_R3.util.CraftMagicNumbers.checkSupported(CraftMagicNumbers.java:314) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.java.JavaPluginLoader.loadPlugin(JavaPluginLoader.java:140) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.loadPlugin(SimplePluginManager.java:393) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.loadPlugins(SimplePluginManager.java:301) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.craftbukkit.v1_19_R3.CraftServer.loadPlugins(CraftServer.java:398) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:9f15450b-1f2dd8e12-7d7b241e]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_7038_(DedicatedServer.java:219) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:890) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [08:07:53 WARN]: could not create Vfs.Dir from url. ignoring the exception and continuing
# org.reflections.ReflectionsException: Could not open url connection
# 	at org.reflections.vfs.JarInputDir$1.<init>(JarInputDir.java:31) ~[?:?]
# 	at org.reflections.vfs.JarInputDir.lambda$getFiles$0(JarInputDir.java:28) ~[?:?]
# 	at org.reflections.Reflections.lambda$scan$2(Reflections.java:177) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachOp$OfRef.accept(ForEachOps.java:184) ~[?:?]
# 	at java.util.HashMap$KeySpliterator.forEachRemaining(HashMap.java:1715) ~[?:?]
# 	at java.util.stream.AbstractPipeline.copyInto(AbstractPipeline.java:509) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachTask.compute(ForEachOps.java:291) ~[?:?]
# 	at java.util.concurrent.CountedCompleter.exec(CountedCompleter.java:754) ~[?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) ~[?:?]
# 	at java.util.concurrent.ForkJoinTask.invoke(ForkJoinTask.java:667) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachOp.evaluateParallel(ForEachOps.java:160) ~[?:?]
# 	at java.util.stream.ForEachOps$ForEachOp$OfRef.evaluateParallel(ForEachOps.java:174) ~[?:?]
# 	at java.util.stream.AbstractPipeline.evaluate(AbstractPipeline.java:233) ~[?:?]
# 	at java.util.stream.ReferencePipeline.forEach(ReferencePipeline.java:596) ~[?:?]
# 	at java.util.stream.ReferencePipeline$Head.forEach(ReferencePipeline.java:765) ~[?:?]
# 	at org.reflections.Reflections.scan(Reflections.java:173) ~[?:?]
# 	at org.reflections.Reflections.<init>(Reflections.java:126) ~[?:?]
# 	at org.reflections.Reflections.<init>(Reflections.java:159) ~[?:?]
# 	at com.aregcraft.reforging.api.DeltaPlugin.<init>(DeltaPlugin.java:25) ~[?:?]
# 	at com.aregcraft.reforging.Reforging.<init>(Reforging.java:22) ~[?:?]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.ReflectAccess.newInstance(ReflectAccess.java:128) ~[?:?]
# 	at jdk.internal.reflect.ReflectionFactory.newInstance(ReflectionFactory.java:304) ~[?:?]
# 	at java.lang.Class.newInstance(Class.java:725) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.<init>(PluginClassLoader.java:99) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.java.JavaPluginLoader.loadPlugin(JavaPluginLoader.java:144) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.loadPlugin(SimplePluginManager.java:393) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.loadPlugins(SimplePluginManager.java:301) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.craftbukkit.v1_19_R3.CraftServer.loadPlugins(CraftServer.java:398) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:9f15450b-1f2dd8e12-7d7b241e]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_7038_(DedicatedServer.java:219) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:890) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# Caused by: java.io.IOException: no entry name specified
# 	at sun.net.www.protocol.jar.JarURLConnection.getInputStream(JarURLConnection.java:159) ~[?:?]
# 	at java.net.URL.openStream(URL.java:1325) ~[?:?]
# 	at com.mohistmc.bukkit.remapping.RemapSourceHandler$RemapSourceConnection.connect(RemapSourceHandler.java:59) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at com.mohistmc.bukkit.remapping.RemapSourceHandler$RemapSourceConnection.getInputStream(RemapSourceHandler.java:73) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.reflections.vfs.JarInputDir$1.<init>(JarInputDir.java:30) ~[?:?]
# 	... 33 more
# [08:07:53 INFO]: Reflections took 19 ms to scan 1 urls, producing 0 keys and 0 values
# [08:07:53 INFO]: Reflections took 7 ms to scan 1 urls, producing 61 keys and 88 values
# [08:07:57 INFO]: [PlaceholderAPI] Loading PlaceholderAPI v2.11.5
# [08:07:57 INFO]: [ClearLag] Loading ClearLag v3.2.2
# [08:07:57 INFO]: [SimpleRename] Loading SimpleRename v13.9
# [08:07:57 INFO]: [PlugMan] Loading PlugMan v2.1.7
# [08:07:57 INFO]: [HolographicDisplays] Loading HolographicDisplays v3.0.4
# [08:07:57 INFO]: [SimpleTpa] Loading SimpleTpa v6.6
# [08:07:57 INFO]: [AutoTotem] Loading AutoTotem v1.2.2
# [08:07:57 INFO]: [playit-gg] Loading playit-gg v0.1.4
# [08:07:57 INFO]: [EnchantPlus] Loading EnchantPlus v1.3.5
# [08:07:57 INFO]: [Reforging] Loading Reforging v5.4.2
# [08:07:57 INFO]: [ViaVersion] Loading ViaVersion v4.9.2
# [08:07:57 INFO]: [ViaVersion] ViaVersion 4.9.2 is now loaded. Registering protocol transformers and injecting...
# [08:07:58 INFO]: [ViaVersion] Loading block connection mappings ...
# [08:07:59 INFO]: [ViaVersion] Using FastUtil Long2ObjectOpenHashMap for block connections
# [08:07:59 INFO]: [ViaBackwards] Loading translations...
# [08:07:59 INFO]: [ViaBackwards] Registering protocols...
# [08:08:00 INFO]: [ViaBackwards] Loading ViaBackwards v4.9.1
# [08:08:00 INFO]: [ViaRewind] Loading ViaRewind v3.0.5
# [08:08:00 INFO]: [LuckPerms] Loading LuckPerms v5.4.40
# [08:08:00 INFO]: [InfinityStones] Loading InfinityStones v1.47
# [08:08:00 INFO]: [AnimatedScoreboard] Loading AnimatedScoreboard v0.3.0
# [08:08:00 INFO]: [SkinsRestorer] Loading SkinsRestorer v15.4.0
# [08:08:00 INFO]: [Vault] Loading Vault v1.7.3-b131
# [08:08:00 INFO]: [WorldEdit] Loading WorldEdit v7.2.14+6360-094b734
# [08:08:01 WARN]: [WorldEdit] Loaded class javax.annotation.Nullable from Reforging v5.4.2 which is not a depend or softdepend of this plugin.
# [08:08:01 INFO]: Got request to register class com.sk89q.worldedit.bukkit.BukkitServerInterface with WorldEdit [com.sk89q.worldedit.extension.platform.PlatformManager@9f289e0]
# [08:08:01 INFO]: [Essentials] Loading Essentials v2.21.0-dev+56-1929d41
# [08:08:01 INFO]: [Multiverse-Core] Loading Multiverse-Core v4.3.12
# [08:08:01 INFO]: [Shopkeepers] Loading Shopkeepers v2.19.0
# [08:08:02 WARN]: Initializing Legacy Material Support. Unless you have legacy plugins and/or data this is a bug!
# [08:08:05 INFO]: [Shopkeepers] Loaded all plugin classes (3907 ms).
# [08:08:05 INFO]: [Shopkeepers] Loading config.
# [08:08:05 WARN]: [Shopkeepers] Config: Forcefully enabled 'disable-inventory-verification' to resolve a known incompatibility with Mohist servers.
# [08:08:05 INFO]: [Shopkeepers] Loading language file: language-en-default.yml
# [08:08:05 INFO]: [Shopkeepers] Registering defaults.
# [08:08:05 INFO]: [TabList] Loading TabList v5.7.0
# [08:08:05 INFO]: [EssentialsChat] Loading EssentialsChat v2.21.0-dev+56-1929d41
# [08:08:05 INFO]: [EconomyShopGUI] Loading EconomyShopGUI v5.5.0
# [08:08:05 INFO]: [ChatManager] Loading ChatManager v3.7.7
# [08:08:05 INFO]: [AngelChest] Loading AngelChest v11.0.1
# [08:08:06 INFO]: [Reforging] Enabling Reforging v5.4.2
# [08:08:06 ERROR]: Error occurred while enabling Reforging v5.4.2 (Is it up to date?)
# com.google.common.util.concurrent.UncheckedExecutionException: java.lang.NullPointerException
# 	at com.google.common.cache.LocalCache$Segment.get(LocalCache.java:2055) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.google.common.cache.LocalCache.get(LocalCache.java:3966) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.google.common.cache.LocalCache.getOrLoad(LocalCache.java:3989) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.google.common.cache.LocalCache$LocalLoadingCache.get(LocalCache.java:4950) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.aregcraft.reforging.api.json.JsonConfigurationLoader.get(JsonConfigurationLoader.java:83) ~[?:?]
# 	at com.aregcraft.reforging.api.json.JsonConfigurationLoader.get(JsonConfigurationLoader.java:91) ~[?:?]
# 	at com.aregcraft.reforging.api.json.JsonConfigurationLoader.get(JsonConfigurationLoader.java:77) ~[?:?]
# 	at com.aregcraft.reforging.Reforging.getReforgingAnvil(Reforging.java:54) ~[?:?]
# 	at com.aregcraft.reforging.Reforging.onEnable(Reforging.java:44) ~[?:?]
# 	at org.bukkit.plugin.java.JavaPlugin.setEnabled(JavaPlugin.java:266) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.java.JavaPluginLoader.enablePlugin(JavaPluginLoader.java:335) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.enablePlugin(SimplePluginManager.java:479) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.craftbukkit.v1_19_R3.CraftServer.enablePlugin(CraftServer.java:511) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:9f15450b-1f2dd8e12-7d7b241e]
# 	at org.bukkit.craftbukkit.v1_19_R3.CraftServer.enablePlugins(CraftServer.java:423) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:9f15450b-1f2dd8e12-7d7b241e]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_7038_(DedicatedServer.java:220) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:890) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# Caused by: java.lang.NullPointerException
# 	at java.util.Objects.requireNonNull(Objects.java:233) ~[?:?]
# 	at java.nio.file.Files.copy(Files.java:3108) ~[?:?]
# 	at com.aregcraft.reforging.api.json.JsonConfigurationLoader$PluginCacheLoader.load(JsonConfigurationLoader.java:176) ~[?:?]
# 	at com.aregcraft.reforging.api.json.JsonConfigurationLoader$PluginCacheLoader.load(JsonConfigurationLoader.java:170) ~[?:?]
# 	at com.google.common.cache.LocalCache$LoadingValueReference.loadFuture(LocalCache.java:3533) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.google.common.cache.LocalCache$Segment.loadSync(LocalCache.java:2282) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.google.common.cache.LocalCache$Segment.lockedGetOrLoad(LocalCache.java:2159) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.google.common.cache.LocalCache$Segment.get(LocalCache.java:2049) ~[guava-31.1-jre.jar%23124!/:?]
# 	... 17 more
# [08:08:06 INFO]: [Reforging] Disabling Reforging v5.4.2
# [08:08:06 INFO]: [ViaRewind] Enabling ViaRewind v3.0.5
# [08:08:06 INFO]: [LuckPerms] Enabling LuckPerms v5.4.40
# [08:08:06 INFO]:         __
# [08:08:06 INFO]:   |    |__)   LuckPerms v5.4.40
# [08:08:06 INFO]:   |___ |      Running on Bukkit - Mohist
# [08:08:06 INFO]:
# [08:08:06 INFO]: [LuckPerms] Loading configuration...
# [08:08:07 INFO]: [LuckPerms] Loading storage provider... [H2]
# [08:08:08 INFO]: [LuckPerms] Loading internal permission managers...
# [08:08:08 INFO]: [LuckPerms] Performing initial data load...
# [08:08:08 INFO]: [LuckPerms] Successfully enabled. (took 2937ms)
# [08:08:08 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.4.0
# [08:08:09 INFO]: [SkinsRestorer] Renaming customGUI.enabled to gui.custom.enabled
# [08:08:09 INFO]: [SkinsRestorer] Renaming customGUI.showOnlyCustomGUI to gui.custom.onlyShowList
# [08:08:09 INFO]: [SkinsRestorer] Renaming customGUI.list to gui.custom.list
# [08:08:10 ERROR]: An unexpected error occurred while starting the plugin. Please check the console for more details.
# java.lang.NoSuchMethodError: 'com.viaversion.viaversion.api.protocol.version.ProtocolVersion com.viaversion.viaversion.api.protocol.version.ServerProtocolVersion.lowestSupportedProtocolVersion()'
# 	at net.skinsrestorer.bukkit.refresher.ViaWorkaround.shouldApplyWorkaround(ViaWorkaround.java:35) ~[?:?]
# 	at net.skinsrestorer.bukkit.SRBukkitInit.selectSpigotRefresher(SRBukkitInit.java:125) ~[?:?]
# 	at net.skinsrestorer.bukkit.SRBukkitInit.detectRefresh(SRBukkitInit.java:121) ~[?:?]
# 	at net.skinsrestorer.bukkit.SRBukkitInit.initSkinApplier(SRBukkitInit.java:77) ~[?:?]
# 	at net.skinsrestorer.shared.plugin.SRPlugin.startup(SRPlugin.java:323) ~[?:?]
# 	at net.skinsrestorer.shared.plugin.SRBootstrapper.startPlugin(SRBootstrapper.java:62) ~[?:?]
# 	at net.skinsrestorer.bukkit.SRBukkitBootstrap.onEnable(SRBukkitBootstrap.java:45) ~[?:?]
# 	at org.bukkit.plugin.java.JavaPlugin.setEnabled(JavaPlugin.java:266) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.java.JavaPluginLoader.enablePlugin(JavaPluginLoader.java:335) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.enablePlugin(SimplePluginManager.java:479) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.craftbukkit.v1_19_R3.CraftServer.enablePlugin(CraftServer.java:511) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:9f15450b-1f2dd8e12-7d7b241e]
# 	at org.bukkit.craftbukkit.v1_19_R3.CraftServer.enablePlugins(CraftServer.java:423) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:9f15450b-1f2dd8e12-7d7b241e]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_7038_(DedicatedServer.java:220) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:890) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [08:08:10 WARN]: Updater was not initialized, a error occurred while starting the plugin. Forcing updater to initialize.
# [08:08:10 INFO]: [Vault] Enabling Vault v1.7.3-b131
# [08:08:11 WARN]: [Vault] Loaded class com.earth2me.essentials.api.Economy from Essentials v2.21.0-dev+56-1929d41 which is not a depend or softdepend of this plugin.
# [08:08:11 INFO]: [Vault] [Economy] Essentials Economy found: Waiting
# [08:08:12 INFO]: [Vault] [Permission] SuperPermissions loaded as backup permission system.
# [08:08:12 INFO]: [Vault] Enabled Version 1.7.3-b131
# [08:08:12 INFO]: [LuckPerms] Registered Vault permission & chat hook.
# [08:08:12 INFO]: [WorldEdit] Enabling WorldEdit v7.2.14+6360-094b734
# [08:08:12 INFO]: Registering commands with com.sk89q.worldedit.bukkit.BukkitServerInterface
# [08:08:12 INFO]: WEPIF: Vault detected! Using Vault for permissions
# [08:08:14 INFO]: Using com.sk89q.worldedit.bukkit.adapter.impl.v1_19_R3.PaperweightAdapter as the Bukkit adapter
# [08:08:15 INFO]: [WorldEdit] ====================================================
# [08:08:15 INFO]: [WorldEdit]  WorldEdit works better if you use Paper
# [08:08:15 INFO]: [WorldEdit]  as your server software.
# [08:08:15 INFO]: [WorldEdit]
# [08:08:15 INFO]: [WorldEdit]  Paper offers significant performance improvements,
# [08:08:15 INFO]: [WorldEdit]  bug fixes, security enhancements and optional
# [08:08:15 INFO]: [WorldEdit]  features for server owners to enhance their server.
# [08:08:15 INFO]: [WorldEdit]
# [08:08:15 INFO]: [WorldEdit]  Paper includes Timings v2, which is significantly
# [08:08:15 INFO]: [WorldEdit]  better at diagnosing lag problems over v1.
# [08:08:15 INFO]: [WorldEdit]
# [08:08:15 INFO]: [WorldEdit]  All of your plugins should still work, and the
# [08:08:15 INFO]: [WorldEdit]  Paper community will gladly help you fix any issues.
# [08:08:15 INFO]: [WorldEdit]
# [08:08:15 INFO]: [WorldEdit]  Join the Paper Community @ https://papermc.io
# [08:08:15 INFO]: [WorldEdit] ====================================================
# [08:08:15 INFO]: Loading JourneyMap Forge Configs
# [08:08:15 INFO]: Server configuration has been reloaded
# [08:08:15 INFO]: Loading server config for pickupnotifier
# [08:08:15 INFO]: Server configuration has been reloaded
# [08:08:15 INFO]: Loading server config for hangglider
# [08:08:15 INFO]: Reloading server config for hangglider
# [08:08:15 INFO]: Loading server config for bettertridents
# [08:08:15 INFO]: Reloading server config for hangglider
# [08:08:15 INFO]: Loading server config for enchantinginfuser
# [08:08:15 INFO]: Reloading server config for enchantinginfuser
# [08:08:15 INFO]: Preparing level "world"
# [08:08:26 INFO]: Preparing start region for dimension minecraft:overworld
# [08:08:26 INFO]: Preparing spawn area: 0%
# [08:08:26 INFO]: Preparing spawn area: 2%
# [08:08:27 INFO]: Preparing spawn area: 88%
# [08:08:27 INFO]: Preparing spawn area: 88%
# [08:08:28 INFO]: Preparing spawn area: 88%
# [08:08:28 INFO]: Preparing spawn area: 89%
# [08:08:29 INFO]: Preparing spawn area: 89%
# [08:08:29 INFO]: Preparing spawn area: 89%
# [08:08:30 INFO]: Preparing spawn area: 89%
# [08:08:30 INFO]: Time elapsed: 4510 ms
# [08:08:30 INFO]: Preparing start region for dimension minecraft:the_end
# [08:08:31 INFO]: Preparing spawn area: 0%
# [08:08:31 INFO]: Preparing spawn area: 0%
# [08:08:31 INFO]: Preparing spawn area: 0%
# [08:08:32 INFO]: Preparing spawn area: 0%
# [08:08:32 INFO]: Preparing spawn area: 17%
# [08:08:33 INFO]: Time elapsed: 2390 ms
# [08:08:33 INFO]: Preparing start region for dimension minecraft:the_nether
# [08:08:33 INFO]: Preparing spawn area: 0%
# [08:08:33 INFO]: Preparing spawn area: 0%
# [08:08:34 INFO]: Preparing spawn area: 0%
# [08:08:34 INFO]: Preparing spawn area: 15%
# [08:08:35 INFO]: Preparing spawn area: 73%
# [08:08:35 INFO]: Time elapsed: 2098 ms
# [08:08:35 INFO]: [PlaceholderAPI] Enabling PlaceholderAPI v2.11.5
# [08:08:35 INFO]: [PlaceholderAPI] Fetching available expansion information...
# [08:08:35 INFO]: [ClearLag] Enabling ClearLag v3.2.2
# [08:08:35 INFO]: [ClearLag] Using version-adapter: LatestVersionAdapter
# [08:08:35 INFO]: [ClearLag] Loading modules...
# [08:08:35 WARN]: [ClearLag] Clearlag failed to use the internal TPS tracker during initialization. Reverted to estimation... (net.minecraft.server.v1_19_R3.MinecraftServer)
# [08:08:35 INFO]: [ClearLag] Modules enabed, loading config values
# [08:08:35 INFO]: [ClearLag] Modules have been loaded!
# [08:08:35 INFO]: [ClearLag] Clearlag is now enabled!
# [08:08:35 INFO]: [ClearLag] Checking for updates compatible with your bukkit version [1.19]...
# [08:08:35 INFO]: [SimpleRename] Enabling SimpleRename v13.9
# [08:08:35 INFO]: SimpleRename enabled!
# [08:08:35 INFO]: [PlugMan] Enabling PlugMan v2.1.7
# [08:08:35 INFO]: [HolographicDisplays] Enabling HolographicDisplays v3.0.4
# [08:08:35 INFO]: [ClearLag] No updates found!
# [08:08:36 INFO]: [SimpleTpa] Enabling SimpleTpa v6.6
# [08:08:36 INFO]: [SimpleTpa] If you need support contact me at https://discord.gg/SZUkza9
# [08:08:36 INFO]: [SimpleTpa] Simple Tpa has been enabled on version 6.6
# [08:08:36 INFO]: Enabled metrics. You may opt-out by changing plugins/bStats/config.yml
# [08:08:36 INFO]: [AutoTotem] Enabling AutoTotem v1.2.2
# [08:08:36 INFO]: [AutoTotem] AutoTotem has started!
# [08:08:36 INFO]: [playit-gg] Enabling playit-gg v0.1.4
# [08:08:36 INFO]: secret key found, checking
# [08:08:36 INFO]: check secret
# [08:08:36 INFO]: [EnchantPlus] Enabling EnchantPlus v1.3.5
# [08:08:36 INFO]: [EnchantPlus] Language en loaded.
# [08:08:36 INFO]: [EnchantPlus] This plugin is using Metrics by BtoBastian.
# [08:08:36 INFO]: [EnchantPlus] Plugin version 1.3.5 enabled! (67 ms)
# [08:08:37 INFO]: [EnchantPlus] There is no update available.
# [08:08:37 INFO]: [ViaVersion] Enabling ViaVersion v4.9.2
# [08:08:37 INFO]: [ViaBackwards] Enabling ViaBackwards v4.9.1
# [08:08:37 INFO]: [InfinityStones] Enabling InfinityStones v1.47
# [08:08:37 INFO]: InfinityStones has been enabled!
# [08:08:37 INFO]: [AnimatedScoreboard] Enabling AnimatedScoreboard v0.3.0
# [08:08:37 INFO]: [PlaceholderAPI] Successfully registered internal expansion: animatedscoreboard [0.0.1]
# [08:08:37 INFO]: [Essentials] Enabling Essentials v2.21.0-dev+56-1929d41
# [08:08:37 INFO]: found minecraft java tunnel: ms-gaming.joinmc.link
# [08:08:37 INFO]: keys and tunnel setup
# [08:08:37 WARN]: Got IO error working with :control.playit.gg/2602:fbaf:814:0:0:0:0:1, error : java.net.SocketException: Network is unreachable
# [08:08:37 INFO]: request queued, waiting 1 second before resend
# [08:08:37 ERROR]: You are running a server that does not properly support Bukkit plugins. Bukkit plugins should not be used with Forge/Fabric mods! For Forge: Consider using ForgeEssentials, or SpongeForge + Nucleus.
# [08:08:37 INFO]: Status determining class: net.minecraftforge.common.MinecraftForge
# [08:08:38 INFO]: Attempting to convert old kits in config.yml to new kits.yml
# [08:08:38 INFO]: No kits found to migrate.
# [08:08:38 INFO]: Loaded 39095 items from items.json.
# [08:08:38 INFO]: Using locale en
# [08:08:38 INFO]: ServerListPingEvent: Spigot iterator API
# [08:08:38 INFO]: Starting Metrics. Opt-out using the global bStats config.
# [08:08:38 INFO]: [Vault] [Economy] Essentials Economy hooked.
# [08:08:38 INFO]: Using Vault based permissions (LuckPerms)
# [08:08:38 INFO]: [Multiverse-Core] Enabling Multiverse-Core v4.3.12
# [08:08:38 WARN]: [Multiverse-Core] "Multiverse-Core v4.3.12" has registered a listener for org.bukkit.event.entity.EntityCreatePortalEvent on method "public void com.onarandombox.MultiverseCore.listeners.MVPortalListener.entityPortalCreate(org.bukkit.event.entity.EntityCreatePortalEvent)", but the event is Deprecated. "Server performance will be affected"; please notify the authors [dumptruckman, Rigby, fernferret, lithium3141, main--].
# [08:08:38 INFO]: [Multiverse-Core] We are aware of the warning about the deprecated event. There is no alternative that allows us to do what we need to do and performance impact is negligible. It is safe to ignore.
# [08:08:38 WARN]: [Multiverse-Core] Exception while loading value for environment
# [08:08:38 WARN]: [Multiverse-Core] Exception while loading value for environment
# [08:08:38 INFO]: request queued, waiting 1 second before resend
# [08:08:40 INFO]: Preparing start region for dimension minecraft:mundo2
# [08:08:40 INFO]: Preparing spawn area: 0%
# [08:08:41 INFO]: Preparing spawn area: 89%
# [08:08:41 INFO]: Preparing spawn area: 89%
# [08:08:42 INFO]: Preparing spawn area: 90%
# [08:08:42 INFO]: Time elapsed: 1973 ms
# [08:08:42 INFO]: [Multiverse-Core] 2 - World(s) loaded.
# [08:08:42 WARN]: [Multiverse-Core] Buscript failed to load! The script command will be disabled! If you would like not to see this message, use `/mv conf enablebuscript false` to disable Buscript from loading.
# [08:08:42 WARN]: [Multiverse-Core] There was an issue while enabling metrics:
# [08:08:42 WARN]: java.lang.NullPointerException: Cannot invoke "org.bukkit.World$Environment.name()" because "env" is null
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.utils.metrics.MetricsConfigurator.titleCaseEnv(MetricsConfigurator.java:76)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.utils.metrics.MetricsConfigurator.lambda$addEnvironmentsMetric$1(MetricsConfigurator.java:70)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.utils.metrics.MetricsHelper.createAdvancedPieChart(MetricsHelper.java:23)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.utils.metrics.MetricsConfigurator.addAdvancedPieMetric(MetricsConfigurator.java:89)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.utils.metrics.MetricsConfigurator.addEnvironmentsMetric(MetricsConfigurator.java:68)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.utils.metrics.MetricsConfigurator.initMetrics(MetricsConfigurator.java:44)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.utils.metrics.MetricsConfigurator.configureMetrics(MetricsConfigurator.java:22)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.MultiverseCore.setupMetrics(MultiverseCore.java:354)
# [08:08:42 WARN]: 	at com.onarandombox.MultiverseCore.MultiverseCore.onEnable(MultiverseCore.java:341)
# [08:08:42 WARN]: 	at TRANSFORMER/forge@45.2.0/org.bukkit.plugin.java.JavaPlugin.setEnabled(JavaPlugin.java:266)
# [08:08:42 WARN]: 	at TRANSFORMER/forge@45.2.0/org.bukkit.plugin.java.JavaPluginLoader.enablePlugin(JavaPluginLoader.java:335)
# [08:08:42 WARN]: 	at TRANSFORMER/forge@45.2.0/org.bukkit.plugin.SimplePluginManager.enablePlugin(SimplePluginManager.java:479)
# [08:08:42 WARN]: 	at TRANSFORMER/forge@45.2.0/org.bukkit.craftbukkit.v1_19_R3.CraftServer.enablePlugin(CraftServer.java:511)
# [08:08:42 WARN]: 	at TRANSFORMER/forge@45.2.0/org.bukkit.craftbukkit.v1_19_R3.CraftServer.enablePlugins(CraftServer.java:423)
# [08:08:42 WARN]: 	at TRANSFORMER/minecraft@1.19.4/net.minecraft.server.MinecraftServer.m_129815_(MinecraftServer.java:480)
# [08:08:42 WARN]: 	at TRANSFORMER/minecraft@1.19.4/net.minecraft.server.MinecraftServer.m_130006_(MinecraftServer.java:385)
# [08:08:42 WARN]: 	at TRANSFORMER/minecraft@1.19.4/net.minecraft.server.dedicated.DedicatedServer.m_7038_(DedicatedServer.java:227)
# [08:08:42 WARN]: 	at TRANSFORMER/minecraft@1.19.4/net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:890)
# [08:08:42 WARN]: 	at TRANSFORMER/minecraft@1.19.4/net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301)
# [08:08:42 WARN]: 	at java.base/java.lang.Thread.run(Thread.java:1583)
# [08:08:42 INFO]: [Multiverse-Core] Version 4.3.12 (API v24) Enabled - By dumptruckman, Rigby, fernferret, lithium3141 and main--
# [08:08:42 INFO]: [Shopkeepers] Enabling Shopkeepers v2.19.0
# [08:08:42 INFO]: [Shopkeepers] Loading the data of 1 shopkeepers ...
# [08:08:42 INFO]: [TabList] Enabling TabList v5.7.0
# [08:08:42 INFO]: [TabList] Hooked PlaceholderAPI version: 2.11.5
# [08:08:42 INFO]: [TabList] > Enabled v5.7.0 (196ms)
# [08:08:42 INFO]: [EssentialsChat] Enabling EssentialsChat v2.21.0-dev+56-1929d41
# [08:08:42 INFO]: [TabList] -------------
# [08:08:42 INFO]: [TabList] New update is available for TabList
# [08:08:42 INFO]: [TabList] Your version: 5.7.0, New version 5.7.6
# [08:08:42 INFO]: [TabList]
# [08:08:42 INFO]: [TabList] To disable update checking, go to the config file
# [08:08:42 INFO]: [TabList] -------------
# [08:08:42 INFO]: [TabList] Downloading new version of TabList...
# [08:08:42 INFO]: Starting Metrics. Opt-out using the global bStats config.
# [08:08:42 INFO]: [EconomyShopGUI] Enabling EconomyShopGUI v5.5.0
# [08:08:42 INFO]: [EconomyShopGUI] [INFO]: Using lang-en.yml as language file.
# [08:08:42 INFO]: [EconomyShopGUI] [INFO]: Shops.yml has been found!
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Sections.yml has been found!
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Successfully hooked into Vault
# [08:08:43 INFO]: [EconomyShopGUI] [DEBUG]: Completed loading '1' economy provider(s) for all 16 shop sections.
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Using minecraft version 1.19.4...
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Spawner provider set to DEFAULT in config
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Using plugin default spawners...
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Debug mode is enabled.
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Updating Shop settings...
# [08:08:43 INFO]: [EconomyShopGUI] [INFO]: Loading all items...
# [08:08:43 INFO]: [EconomyShopGUI] Initialized - Took 491ms to complete
# [08:08:43 INFO]: [ChatManager] Enabling ChatManager v3.7.7
# [08:08:43 INFO]: [ChatManager] Hooked into: PlaceholderAPI v2.11.5
# [08:08:43 INFO]: [PlaceholderAPI] Successfully registered internal expansion: chatmanager [3.7.7]
# [08:08:43 INFO]: [ChatManager] Hooked into: Essentials v2.21.0-dev+56-1929d41
# [08:08:43 INFO]: [ChatManager] Hooked into: Vault v1.7.3-b131
# [08:08:43 INFO]: [ChatManager] Hooked into: LuckPerms v5.4.40
# [08:08:43 INFO]: [ChatManager] Plugin is up to date - v3.7.7
# [08:08:43 INFO]: [ChatManager] Starting Metrics.
# [08:08:43 INFO]: =========================
# [08:08:43 INFO]: Chat Manager
# [08:08:43 INFO]: Version 3.7.7
# [08:08:43 INFO]: Author: H1DD3NxN1NJA
# [08:08:43 INFO]: =========================
# [08:08:43 INFO]: [AngelChest] Enabling AngelChest v11.0.1
# [08:08:43 INFO]: [AngelChest] groups.yml does not exist, skipping custom group settings.
# [08:08:43 INFO]: [AngelChest] blacklist.yml does not exist, disabling item blacklist.
# [08:08:43 INFO]: [AngelChest] Not using premium version, disabling Graveyards feature
# [08:08:43 INFO]: [PlaceholderAPI] Successfully registered internal expansion: angelchest [GENERIC]
# [08:08:43 INFO]: [AngelChest] Successfully hooked into Vault and the EconomyProvider, enabling economy functions.
# [08:08:44 INFO]: [AngelChest] Successfully enabled AngelChest v11.0.1 (Premium: false)
# [08:08:44 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [08:08:44 INFO]: [PlaceholderAPI] Placeholder expansion registration initializing...
# [08:08:44 INFO]: Done (28.552s)! For help, type "help"
# [08:08:44 INFO]: Successfully initialized permission handler forge:default_handler
# [08:08:44 WARN]: [PlaceholderAPI] Loaded class net.ess3.api.IEssentials from Essentials v2.21.0-dev+56-1929d41 which is not a depend or softdepend of this plugin.
# [08:08:44 INFO]: Encoded Weapon Attribute registry size (with package overhead): 32191 bytes (in 4 string chunks with the size of 10000)
# [08:08:44 WARN]: [voicechat] Running in offline mode - Voice chat encryption is not secure!
# [08:08:44 INFO]: [voicechat] Voice chat server started at port 25565
# [08:08:44 ERROR]: [ViaVersion] ViaVersion failed to get the server protocol!
# java.lang.NullPointerException: Failed to get server data
# 	at com.google.common.base.Preconditions.checkNotNull(Preconditions.java:907) ~[guava-31.1-jre.jar%23124!/:?]
# 	at com.viaversion.viaversion.bukkit.platform.BukkitViaInjector.veryCursedProtocolDetection(BukkitViaInjector.java:130) ~[?:?]
# 	at com.viaversion.viaversion.bukkit.platform.BukkitViaInjector.getServerProtocolVersion(BukkitViaInjector.java:70) ~[?:?]
# 	at com.viaversion.viaversion.ViaManagerImpl.loadServerProtocol(ViaManagerImpl.java:188) ~[?:?]
# 	at com.viaversion.viaversion.ViaManagerImpl.onServerLoaded(ViaManagerImpl.java:126) ~[?:?]
# 	at org.bukkit.craftbukkit.v1_19_R3.scheduler.CraftTask.run(CraftTask.java:77) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.craftbukkit.v1_19_R3.scheduler.CraftScheduler.mainThreadHeartbeat(CraftScheduler.java:415) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at net.minecraft.server.MinecraftServer.m_5703_(MinecraftServer.java:1180) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.dedicated.DedicatedServer.m_5703_(DedicatedServer.java:351) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_5705_(MinecraftServer.java:1119) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:944) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [08:08:44 ERROR]: [ViaVersion] Server version has not been loaded yet, cannot register additional listeners
# [08:08:44 INFO]: [SimpleTpa] There is a new update available.
# [08:08:44 INFO]: [SimpleTpa] There is a new update available:
# [08:08:44 INFO]: [SimpleTpa] https://www.spigotmc.org/resources/simple-tpa.64270/
# [08:08:44 INFO]: Essentials found a compatible payment resolution method: Vault Compatibility Layer (v1.7.3-b131)!
# [08:08:44 WARN]: [PlaceholderAPI] Loaded class net.milkbowl.vault.economy.Economy from Vault v1.7.3-b131 which is not a depend or softdepend of this plugin.
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: vault [1.8.1]
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion playerstats due to a missing plugin: PlayerStats
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: plugin [1.1.0]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: objective [4.2.0]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: pinger [1.0.1]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: server [2.6.2]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: servertime [3.2]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: essentials [1.5.2]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: bungee [2.2]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: otherplayer [2.1.0]
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion playertime due to a missing plugin: PlayerTime
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion ServerWebsite due to a missing plugin: ServerWebsite
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: sbtags [1.0.1]
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion lemonmobcoins due to an unknown issue.
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion levelup due to a missing plugin: LevelUp
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion LevelPoints due to a missing plugin: LevelPoints
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: armor [1.0.0]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: player [2.0.4]
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion ontime due to a missing plugin: OnTime
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: world [1.2.2]
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: playerlist [3.0.3]
# [08:08:44 INFO]: Fetching version information...
# [08:08:44 WARN]: [PlaceholderAPI] Cannot load expansion onetimeitem due to a missing plugin: OneTimeItem
# [08:08:44 WARN]: [PlaceholderAPI] Loaded class net.luckperms.api.LuckPerms from LuckPerms v5.4.40 which is not a depend or softdepend of this plugin.
# [08:08:44 INFO]: [PlaceholderAPI] Successfully registered external expansion: luckperms [5.4-R2]
# [08:08:44 INFO]: 15 placeholder hook(s) registered! 5 placeholder hook(s) have an update available.
# [08:08:44 INFO]: [AnimatedScoreboard] Checking for an update!
# [08:08:44 INFO]: [Vault] Checking for Updates ...
# [08:08:44 INFO]: [PlaceholderAPI] An update for PlaceholderAPI (v2.11.6) is available at:
# [08:08:44 INFO]: [PlaceholderAPI] https://www.spigotmc.org/resources/placeholderapi.6245/
# [08:08:44 INFO]: [ViaVersion] Finished mapping loading, shutting down loader executor!
# [08:08:44 INFO]: [Vault] No new version available
# [08:08:44 INFO]: [AnimatedScoreboard] You are 5 versions behind! Get AnimatedScoreboard(v0.3.5) at:
# [08:08:44 INFO]: [AnimatedScoreboard] https://www.spigotmc.org/resources/20848
# [08:08:44 INFO]: [SkinsRestorer] ----------------------------------------------
# [08:08:44 INFO]: [SkinsRestorer]     +==================+
# [08:08:44 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [08:08:44 INFO]: [SkinsRestorer]     |------------------|
# [08:08:44 INFO]: [SkinsRestorer]     |    Error Mode    |
# [08:08:44 INFO]: [SkinsRestorer]     +==================+
# [08:08:44 INFO]: [SkinsRestorer] ----------------------------------------------
# [08:08:44 INFO]: [SkinsRestorer]     Version: 15.4.0
# [08:08:44 INFO]: [SkinsRestorer]     Commit: 7837da9
# [08:08:44 INFO]: [SkinsRestorer]     This is the latest version!
# [08:08:44 INFO]: [SkinsRestorer] ----------------------------------------------
# [08:08:44 WARN]: You're 50 EssentialsX dev build(s) out of date!
# [08:08:44 WARN]: Download it here: https://essentialsx.net/downloads.html
# [08:08:45 WARN]: [AngelChest] ***************************************************
# [08:08:45 WARN]: [AngelChest] * There is a new version of AngelChest available!
# [08:08:45 WARN]: [AngelChest] *
# [08:08:45 WARN]: [AngelChest] * Your version:   11.0.1
# [08:08:45 WARN]: [AngelChest] * Latest version: 13.1.1
# [08:08:45 WARN]: [AngelChest] *
# [08:08:45 WARN]: [AngelChest] * Please update to the newest version.
# [08:08:45 WARN]: [AngelChest] *
# [08:08:45 WARN]: [AngelChest] * Download (Plus):
# [08:08:45 WARN]: [AngelChest] *   https://www.spigotmc.org/resources/88214
# [08:08:45 WARN]: [AngelChest] *
# [08:08:45 WARN]: [AngelChest] * Download (Free):
# [08:08:45 WARN]: [AngelChest] *   https://www.spigotmc.org/resources/60383
# [08:08:45 WARN]: [AngelChest] ***************************************************
# [08:08:45 WARN]: [ViaVersion] There is a newer plugin version available: 5.0.1, you're on: 4.9.2
# [08:08:47 INFO]: [AngelChest] ========================================================
# [08:08:47 INFO]: [AngelChest] You are using the free version of AngelChest. There is
# ...
# 	at net.minecraft.server.level.ServerChunkCache$MainThreadExecutor.m_7245_(ServerChunkCache.java:588) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.level.ServerChunkCache.m_8466_(ServerChunkCache.java:286) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_129961_(MinecraftServer.java:1062) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_7245_(MinecraftServer.java:1051) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.util.thread.BlockableEventLoop.m_18701_(BlockableEventLoop.java:139) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130012_(MinecraftServer.java:1037) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:948) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [08:40:02 WARN]: Skipping BlockEntity with id minecraft:sculk_sensor
# [08:40:02 ERROR]: Failed to create block entity minecraft:sculk_sensor
# java.lang.ClassCastException: class net.minecraft.world.level.block.AirBlock cannot be cast to class net.minecraft.world.level.block.SculkSensorBlock (net.minecraft.world.level.block.AirBlock and net.minecraft.world.level.block.SculkSensorBlock are in module minecraft@1.19.4 of loader 'TRANSFORMER' @149274cb)
# 	at net.minecraft.world.level.block.entity.SculkSensorBlockEntity.<init>(SculkSensorBlockEntity.java:31) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.world.level.block.entity.BlockEntityType.m_155264_(BlockEntityType.java:91) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.world.level.block.entity.BlockEntity.m_155236_(BlockEntity.java:135) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.util.Optional.map(Optional.java:260) ~[?:?]
# 	at net.minecraft.world.level.block.entity.BlockEntity.m_155241_(BlockEntity.java:133) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.world.level.chunk.storage.ChunkSerializer.m_196900_(ChunkSerializer.java:437) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.world.level.chunk.LevelChunk.m_62952_(LevelChunk.java:475) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.level.ChunkMap.lambda$protoChunkToFullChunk$33(ChunkMap.java:747) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at com.mojang.datafixers.util.Either.lambda$mapLeft$0(Either.java:162) ~[datafixerupper-6.0.6.jar%23141!/:?]
# 	at com.mojang.datafixers.util.Either$Left.map(Either.java:38) ~[datafixerupper-6.0.6.jar%23141!/:?]
# 	at com.mojang.datafixers.util.Either.mapLeft(Either.java:162) ~[datafixerupper-6.0.6.jar%23141!/:?]
# 	at net.minecraft.server.level.ChunkMap.lambda$protoChunkToFullChunk$34(ChunkMap.java:731) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.util.concurrent.CompletableFuture$UniApply.tryFire(CompletableFuture.java:646) ~[?:?]
# 	at java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482) ~[?:?]
# 	at net.minecraft.server.level.ChunkTaskPriorityQueueSorter.m_143188_(ChunkTaskPriorityQueueSorter.java:62) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.util.thread.BlockableEventLoop.m_6367_(BlockableEventLoop.java:156) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.level.ServerChunkCache$MainThreadExecutor.m_6367_(ServerChunkCache.java:579) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.util.thread.BlockableEventLoop.m_7245_(BlockableEventLoop.java:130) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.level.ServerChunkCache$MainThreadExecutor.m_7245_(ServerChunkCache.java:588) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.level.ServerChunkCache.m_8466_(ServerChunkCache.java:286) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_129961_(MinecraftServer.java:1062) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_7245_(MinecraftServer.java:1051) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.util.thread.BlockableEventLoop.m_18701_(BlockableEventLoop.java:139) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130012_(MinecraftServer.java:1037) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:948) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.MinecraftServer.m_206580_(MinecraftServer.java:301) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# [08:40:02 WARN]: Skipping BlockEntity with id minecraft:sculk_sensor
# [08:40:04 INFO]: MonsterSR issued server command: /tp Len_027 m
# [08:40:05 INFO]: MonsterSR issued server command: /tp Len_027 MonsterSR
# [08:40:08 INFO]: MonsterSR issued server command: /gm sp
# [08:40:10 INFO]: MonsterSR issued server command: /gm s
# [08:40:48 INFO]: send keep alive
# [08:40:48 INFO]: MonsterSR issued server command: /gm c
# [08:42:06 INFO]: MonsterSR issued server command: /g m s
# [08:42:08 INFO]: MonsterSR issued server command: /gm s
# [08:42:58 INFO]: MonsterSR issued server command: /feed
# [08:43:07 INFO]: Len_027 issued server command: /give Len_027 bow
# [08:43:15 INFO]: MonsterSR issued server command: /feed
# [08:43:29 INFO]: Len_027 has made the advancement [A Burning Arena]
# [08:44:22 INFO]: MonsterSR has made the advancement [The Imperfect thing]
# [08:44:24 INFO]: MonsterSR issued server command: /feed
# [08:44:49 INFO]: send keep alive
# [08:45:02 INFO]: MonsterSR issued server command: /feed
# [08:45:11 INFO]: Len_027 has made the advancement [The Imperfect thing]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [08:48:01 INFO]: MonsterSR issued server command: /difficulty hard
# [08:48:01 INFO]: [MonsterSR: The difficulty has been set to Hard]
# [08:48:32 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:48:46 INFO]: Len_027 issued server command: /revive Len_027
# [08:48:50 INFO]: send keep alive
# [08:49:06 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:49:11 INFO]: Len_027 issued server command: /revive Len_027
# [08:49:32 INFO]: Len_027 issued server command: /give Len_027 golden_apple 64
# [08:51:31 INFO]: MonsterSR issued server command: /feed
# [08:52:51 INFO]: send keep alive
# [08:52:52 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:52:56 INFO]: Len_027 issued server command: /revive Len_027
# [08:53:00 INFO]: Len_027 is bleeding. Len_027 was burnt to a crisp whilst fighting Ignis
# [08:53:02 INFO]: Len_027 issued server command: /revive Len_027
# [08:53:16 INFO]: MonsterSR issued server command: /feed
# [08:53:28 INFO]: MonsterSR issued server command: /feed
# [08:53:37 INFO]: MonsterSR has completed the challenge [The Extinguished Fire]
# [08:53:41 INFO]: Len_027 is bleeding. Len_027 tried to swim in lava to escape Ignis
# [08:53:46 INFO]: Created new backpack backup file for Len_027 with unique ID 7556a370-5d58-41ce-9eb9-5f346c6667a2
# [08:53:46 INFO]: Your backpack has been placed at X: -3394 Y: 54 Z: -36
# [08:53:46 INFO]: Len_027 tried to swim in lava to escape Ignis
# [08:53:46 INFO]: Len_027 issued server command: /revive Len_027
# [08:53:46 INFO]: Len_027 is bleeding. Len_027 tried to swim in lava
# [08:53:48 INFO]: Len_027 tried to swim in lava
# [08:53:51 WARN]: New entity has data, contents assigned.
# [08:53:54 INFO]: Len_027 issued server command: /actp 2
# [08:53:56 INFO]: [AngelChest] MonsterSR opened the AngelChest of Len_027 at Location{world=CraftWorld{name=mundo2},x=-3394.0,y=55.0,z=-36.0,pitch=0.0,yaw=0.0}
# [08:54:05 INFO]: MonsterSR issued server command: /feed
# [08:55:42 INFO]: Len_027 issued server command: /give Len_027 totem
# [08:55:49 INFO]: MonsterSR issued server command: /kit cristalpvp
# [08:56:02 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:56:06 INFO]: Len_027 issued server command: /revive Len_027
# [08:56:50 ERROR]: Could not pass event AsyncPlayerChatEvent to EssentialsChat v2.21.0-dev+56-1929d41
# org.bukkit.event.EventException: null
# 	at org.bukkit.plugin.java.JavaPluginLoader$1.execute(JavaPluginLoader.java:303) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.RegisteredListener.callEvent(RegisteredListener.java:70) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.fireEvent(SimplePluginManager.java:588) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at org.bukkit.plugin.SimplePluginManager.callEvent(SimplePluginManager.java:575) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.chat(ServerGamePacketListenerImpl.java:2877) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.m_243086_(ServerGamePacketListenerImpl.java:1900) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at net.minecraft.server.network.ServerGamePacketListenerImpl.lambda$handleChat$9(ServerGamePacketListenerImpl.java:1747) ~[server-1.19.4-20230314.122934-srg.jar%23287!/:?]
# 	at java.util.concurrent.CompletableFuture$UniAccept.tryFire(CompletableFuture.java:718) ~[?:?]
# 	at java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482) ~[?:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144) ~[?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642) ~[?:?]
# 	at java.lang.Thread.run(Thread.java:1583) [?:?]
# Caused by: java.util.UnknownFormatConversionException: Conversion = 'l'
# 	at org.bukkit.event.player.AsyncPlayerChatEvent.setFormat(AsyncPlayerChatEvent.java:101) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	at com.earth2me.essentials.chat.processing.AbstractChatHandler.handleChatFormat(AbstractChatHandler.java:121) ~[?:?]
# 	at com.earth2me.essentials.chat.processing.ChatHandler$ChatLowest.onPlayerChat(ChatHandler.java:26) ~[?:?]
# 	at jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:103) ~[?:?]
# 	at java.lang.reflect.Method.invoke(Method.java:580) ~[?:?]
# 	at org.bukkit.plugin.java.JavaPluginLoader$1.execute(JavaPluginLoader.java:301) ~[forge-1.19.4-45.2.0-universal.jar%23292!/:?]
# 	... 11 more
# [08:56:50 INFO]: [Miembro] MonsterSR > trailo
# [08:56:52 INFO]: send keep alive
# [08:56:52 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:56:55 INFO]: Len_027 issued server command: /revive Len_027
# [08:56:57 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:56:59 INFO]: Created new backpack backup file for Len_027 with unique ID f79b47aa-56fb-4d88-892a-9567c346206e
# [08:56:59 INFO]: Your backpack has been placed at X: -3396 Y: 65 Z: 0
# [08:56:59 INFO]: Len_027 was blown up by MonsterSR
# [08:56:59 INFO]: Len_027 issued server command: /revive Len_027
# [08:57:00 INFO]: Len_027 is bleeding. Len_027 was blown up by MonsterSR
# [08:57:06 INFO]: Len_027 was blown up by MonsterSR
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [08:57:08 WARN]: New entity has data, contents assigned.
# [08:57:13 INFO]: Len_027 issued server command: /actp 1
# [08:57:19 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:57:24 INFO]: MonsterSR is bleeding. MonsterSR was slain by Ignis
# [08:57:29 INFO]: Len_027 issued server command: /revive Len_027
# [08:57:31 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:57:31 INFO]: MonsterSR issued server command: /revive MonsterSR}
# [08:57:33 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:57:33 INFO]: Len_027 issued server command: /revive Len_027
# [08:57:35 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:57:40 INFO]: Len_027 issued server command: /revive Len_027
# [08:57:49 INFO]: MonsterSR is bleeding. MonsterSR was slain by Ignis
# [08:57:51 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:57:53 INFO]: MonsterSR is bleeding. MonsterSR tried to swim in lava to escape Ignis
# [08:57:55 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:57:56 INFO]: MonsterSR is bleeding. MonsterSR tried to swim in lava to escape Ignis
# [08:57:58 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:00 INFO]: MonsterSR is bleeding. MonsterSR was killed by Len_027 using magic
# [08:58:03 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:04 INFO]: MonsterSR is bleeding. MonsterSR tried to swim in lava to escape Ignis
# [08:58:05 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:58:07 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:07 INFO]: Len_027 issued server command: /revive Len_027
# [08:58:07 INFO]: MonsterSR is bleeding. MonsterSR was slain by Ignis
# [08:58:07 INFO]: Len_027 is bleeding. Len_027 was slain by Ignis
# [08:58:09 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:10 INFO]: MonsterSR is bleeding. MonsterSR tried to swim in lava to escape Ignis
# [08:58:11 INFO]: Created new backpack backup file for Len_027 with unique ID 7af590bc-3e09-4dd5-8c26-4903ebadfa93
# [08:58:11 INFO]: Your backpack has been placed at X: -3388 Y: 62 Z: 1
# [08:58:11 INFO]: Len_027 tried to swim in lava to escape Ignis
# [08:58:11 INFO]: Len_027 issued server command: /revive Len_027
# [08:58:11 INFO]: Len_027 is bleeding. Len_027 tried to swim in lava to escape Ignis
# [08:58:12 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:12 INFO]: MonsterSR is bleeding. MonsterSR was doomed to fall
# [08:58:13 INFO]: Len_027 tried to swim in lava
# [08:58:14 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:15 WARN]: New entity has data, contents assigned.
# [08:58:19 INFO]: MonsterSR is bleeding. MonsterSR was slain by Ignis
# [08:58:20 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:22 INFO]: MonsterSR is bleeding. MonsterSR was doomed to fall
# [08:58:23 INFO]: Len_027 issued server command: /actp 1
# [08:58:24 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:58:26 INFO]: MonsterSR issued server command: /feed
# [08:58:45 INFO]: Len_027 is bleeding. Len_027 tried to swim in lava to escape Ignis
# [08:58:52 INFO]: Len_027 issued server command: /fly
# [08:58:53 INFO]: Len_027 tried to swim in lava to escape Ignis
# [08:58:55 WARN]: New entity has data, contents assigned.
# [08:58:58 INFO]: Len_027 issued server command: /actp 1
# [08:59:06 INFO]: MonsterSR is bleeding. MonsterSR was slain by Ignis
# [08:59:07 INFO]: Len_027 issued server command: /give Len_027 totem
# [08:59:13 INFO]: MonsterSR issued server command: /revive MonsterSR
# [08:59:14 INFO]: MonsterSR issued server command: /feed
# >
